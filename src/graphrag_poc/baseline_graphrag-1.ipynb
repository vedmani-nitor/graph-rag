# %%
from llama_index.embeddings.azure_openai import AzureOpenAIEmbedding
from llama_index.llms.azure_openai import AzureOpenAI
from dotenv import load_dotenv
from llama_index.llms.gemini import Gemini
from llama_index.embeddings.gemini import GeminiEmbedding
import os

load_dotenv()
# Out:
# True

# %%
# llm = AzureOpenAI(
#     model=os.getenv("DEPLOYMENT_NAME"),
#     deployment_name=os.getenv("DEPLOYMENT_NAME"),
#     api_key=os.getenv("AZURE_OPENAI_API_KEY"),
#     azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
#     api_version=os.getenv("OPENAI_API_VERSION"),
#     temperature=0.0,
# )

llm = Gemini(
    model="models/gemini-1.5-flash-latest",
    temperature=0.0,
)

# %%
embed_model = AzureOpenAIEmbedding(
    model="text-embedding-ada-002",
    # deployment_name="my-custom-embedding",
    api_key=os.getenv("AZURE_OPENAI_API_KEY"),
    azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
    api_version=os.getenv("OPENAI_API_VERSION"),
)
embeddings = embed_model.get_text_embedding("Hello, world!")
len(embeddings)
# Out:
# 1536

# %%
from llama_index.core import Settings

Settings.llm = llm
Settings.embed_model = embed_model

# %%
import nest_asyncio

nest_asyncio.apply()

# %%
from llama_index.core import SimpleDirectoryReader

documents = SimpleDirectoryReader(
    "D:\projects\graphrag-poc\data\selection 1"
).load_data()

# %%
from llama_index.graph_stores.neo4j import Neo4jPropertyGraphStore

# Note: used to be `Neo4jPGStore`
graph_store = Neo4jPropertyGraphStore(
    username="neo4j",
    password="12345678",
    url="bolt://localhost:7687",
    database="graph-rag-2",
)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[24], line 4
#       1 from llama_index.graph_stores.neo4j import Neo4jPropertyGraphStore
#       3 # Note: used to be `Neo4jPGStore`
# ----> 4 graph_store = Neo4jPropertyGraphStore(
#       5     username="neo4j",
#       6     password="12345678",
#       7     url="bolt://localhost:7687",
#       8     database="graph-rag-2",
#       9 )
#
# File d:\projects\graphrag-poc\.venv\Lib\site-packages\llama_index\graph_stores\neo4j\neo4j_property_graph.py:169, in Neo4jPropertyGraphStore.__init__(self, username, password, url, database, refresh_schema, sanitize_query_output, enhanced_schema, **neo4j_kwargs)
#     167 self.structured_schema = {}
#     168 if refresh_schema:
# --> 169     self.refresh_schema()
#     170 # Create index for faster imports and retrieval
#     171 self.structured_query(
#     172     f"""CREATE CONSTRAINT IF NOT EXISTS FOR (n:`{BASE_NODE_LABEL}`)
#     173     REQUIRE n.id IS UNIQUE;"""
#     174 )
#
# File d:\projects\graphrag-poc\.venv\Lib\site-packages\llama_index\graph_stores\neo4j\neo4j_property_graph.py:196, in Neo4jPropertyGraphStore.refresh_schema(self)
#     194 def refresh_schema(self) -> None:
#     195     """Refresh the schema."""
# --> 196     node_query_results = self.structured_query(
#     197         node_properties_query,
#     198         param_map={
#     199             "EXCLUDED_LABELS": [
#     200                 *EXCLUDED_LABELS,
#     201                 BASE_ENTITY_LABEL,
#     202                 BASE_NODE_LABEL,
#     203             ]
#     204         },
#     205     )
#     206     node_properties = (
#     207         [el["output"] for el in node_query_results] if node_query_results else []
#     208     )
#     210     rels_query_result = self.structured_query(
#     211         rel_properties_query, param_map={"EXCLUDED_LABELS": EXCLUDED_RELS}
#     212     )
#
# File d:\projects\graphrag-poc\.venv\Lib\site-packages\llama_index\graph_stores\neo4j\neo4j_property_graph.py:587, in Neo4jPropertyGraphStore.structured_query(self, query, param_map)
#     585 param_map = param_map or {}
#     586 try:
# --> 587     data, _, _ = self._driver.execute_query(
#     588         query, database_=self._database, parameters_=param_map
#     589     )
#     590     full_result = [d.data() for d in data]
#     592     if self.sanitize_query_output:
#
# File d:\projects\graphrag-poc\.venv\Lib\site-packages\neo4j\_sync\driver.py:971, in Driver.execute_query(self, query_, parameters_, routing_, database_, impersonated_user_, bookmark_manager_, auth_, result_transformer_, **kwargs)
#     967     raise ValueError(
#     968         f"Invalid routing control value: {routing_!r}"
#     969     )
#     970 with session._pipelined_begin:
# --> 971     return session._run_transaction(
#     972         access_mode,
#     973         TelemetryAPI.DRIVER,
#     974         work,
#     975         (query_str, parameters, result_transformer_),
#     976         {},
#     977     )
#
# File d:\projects\graphrag-poc\.venv\Lib\site-packages\neo4j\_sync\work\session.py:581, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     579 tx = self._transaction
#     580 try:
# --> 581     result = transaction_function(tx, *args, **kwargs)
#     582 except asyncio.CancelledError:
#     583     # if cancellation callback has not been called yet:
#     584     if self._transaction is not None:
#
# File d:\projects\graphrag-poc\.venv\Lib\site-packages\neo4j\_sync\driver.py:1307, in _work(tx, query, parameters, transformer)
#    1301 def _work(
#    1302     tx: ManagedTransaction,
#    1303     query: te.LiteralString,
#    1304     parameters: dict[str, t.Any],
#    1305     transformer: t.Callable[[Result], t.Union[_T]],
#    1306 ) -> _T:
# -> 1307     res = tx.run(query, parameters)
#    1308     return transformer(res)
#
# File d:\projects\graphrag-poc\.venv\Lib\site-packages\neo4j\_sync\work\transaction.py:195, in TransactionBase.run(self, query, parameters, **kwparameters)
#     192 self._results.append(result)
#     194 parameters = dict(parameters or {}, **kwparameters)
# --> 195 result._tx_ready_run(query, parameters)
#     197 return result
#
# File d:\projects\graphrag-poc\.venv\Lib\site-packages\neo4j\_sync\work\result.py:175, in Result._tx_ready_run(self, query, parameters)
#     171 def _tx_ready_run(self, query, parameters):
#     172     # BEGIN+RUN does not carry any extra on the RUN message.
#     173     # BEGIN {extra}
#     174     # RUN "query" {parameters} {extra}
# --> 175     self._run(query, parameters, None, None, None, None, None, None)
#
# File d:\projects\graphrag-poc\.venv\Lib\site-packages\neo4j\_sync\work\result.py:231, in Result._run(self, query, parameters, db, imp_user, access_mode, bookmarks, notifications_min_severity, notifications_disabled_classifications)
#     229 self._pull()
#     230 self._connection.send_all()
# --> 231 self._attach()
#
# File d:\projects\graphrag-poc\.venv\Lib\site-packages\neo4j\_sync\work\result.py:425, in Result._attach(self)
#     423 if self._exhausted is False:
#     424     while self._attached is False:
# --> 425         self._connection.fetch_message()
#
# File d:\projects\graphrag-poc\.venv\Lib\site-packages\neo4j\_sync\io\_common.py:184, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#     182 def inner(*args, **kwargs):
#     183     try:
# --> 184         func(*args, **kwargs)
#     185     except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#     186         assert not asyncio.iscoroutinefunction(self.__on_error)
#
# File d:\projects\graphrag-poc\.venv\Lib\site-packages\neo4j\_sync\io\_bolt.py:994, in Bolt.fetch_message(self)
#     990 # Receive exactly one message
#     991 tag, fields = self.inbox.pop(
#     992     hydration_hooks=self.responses[0].hydration_hooks
#     993 )
# --> 994 res = self._process_message(tag, fields)
#     995 self.idle_since = monotonic()
#     996 return res
#
# File d:\projects\graphrag-poc\.venv\Lib\site-packages\neo4j\_sync\io\_bolt5.py:496, in Bolt5x0._process_message(self, tag, fields)
#     494 self._server_state_manager.state = self.bolt_states.FAILED
#     495 try:
# --> 496     response.on_failure(summary_metadata or {})
#     497 except (ServiceUnavailable, DatabaseUnavailable):
#     498     if self.pool:
#
# File d:\projects\graphrag-poc\.venv\Lib\site-packages\neo4j\_sync\io\_common.py:254, in Response.on_failure(self, metadata)
#     252 handler = self.handlers.get("on_summary")
#     253 Util.callback(handler)
# --> 254 raise self._hydrate_error(metadata)
#
# ClientError: {code: Neo.ClientError.Database.DatabaseNotFound} {message: Database does not exist. Database name: 'graph-rag-2'.}

# %%
from llama_index.core.node_parser import SentenceSplitter

splitter = SentenceSplitter(
    chunk_size=1024,
    chunk_overlap=20,
)
nodes = splitter.get_nodes_from_documents(documents)
len(nodes)
# create a list of lists each of 10 nodes
nodes_list = [nodes[i : i + 10] for i in range(0, len(nodes), 10)]
print(len(nodes_list))
# Out:
# 7

# %%
from llama_index.core.indices.property_graph import DynamicLLMPathExtractor

dyn_llm_path_extractor = DynamicLLMPathExtractor(
    llm=llm,
    allowed_entity_props=["description"],
    allowed_relation_props=["description"],
)

# %%
from llama_index.core import PropertyGraphIndex
# from llama_index.core.indices.property_graph import SimpleLLMPathExtractor

# index = PropertyGraphIndex(
#     nodes_list[0],
#     embed_model=embed_model,
#     kg_extractors=[
#         dyn_llm_path_extractor
#     ],
#     property_graph_store=graph_store,
#     show_progress=True,
# )

index = PropertyGraphIndex.from_existing(
    property_graph_store=graph_store,
    llm=llm,
    embed_model=embed_model,
    kg_extractors=[dyn_llm_path_extractor],
    show_progress=True,
)

# %%
from llama_index.core.indices.property_graph import VectorContextRetriever

vector_retriever = VectorContextRetriever(
    index.property_graph_store,
    # only needed when the graph store doesn't support vector queries
    # vector_store=index.vector_store,
    embed_model=embed_model,
    # include source chunk text with retrieved paths
    include_text=True,
    # the number of nodes to fetch
    similarity_top_k=10,
    # the depth of relations to follow after node retrieval
    path_depth=2,
    # can provide any other kwargs for the VectorStoreQuery class
)

# %%
from llama_index.core.response_synthesizers import TreeSummarize
tree_summarize = TreeSummarize(verbose=False)

# %%
query_engine = index.as_query_engine(
    include_text=True,
    # sub_retrievers=[vector_retriever],
    similarity_top_k=10,
    path_depth=2,
    response_synthesizer=tree_summarize,
)
response = query_engine.query(
    "Provide all the information available related to Viaweb. Answer in 400 words."
)
print(response)
# Out:
# Viaweb, founded by Robert Morris and another individual (age 29 and 30 respectively at the time of founding), was a startup that eventually became Anomaly.  The founders, despite being relatively older, maintained a frugal lifestyle similar to that of 23-year-olds, possessing minimal assets. This lack of financial burden proved advantageous, allowing for flexibility and a cost-conscious approach to business.  Their pricing strategy reflected this mindset; they offered services at a significantly lower price point than competitors, a daring move that ultimately contributed to their success.  This low-cost approach mirrored the strategy of Apple II, which also benefited from its affordability.
#
# Viaweb successfully raised $2.5 million in funding from angel investors without ever agreeing to vesting. This was unusual for such a large funding amount, as vesting is typically the norm.  The founders' inexperience led to their initial aversion to vesting, a decision that ultimately proved beneficial in protecting their autonomy and preventing undue influence from investors.  The angel investment marked a particularly happy period for the company, allowing them to focus on product development and hiring without immediate financial concerns.  This period of high productivity was described as similar to a post-doctoral experience.
#
# Following the angel funding, Viaweb hired its first employee, initially as a consultant, offering a small salary and 3% equity in restricted stock with a four-year vesting period.  The company also invested in a freelance graphic designer.  The founders' experience highlights the importance of early hiring and the significant equity often granted to early employees, with the amount decreasing over time.  The company's growth was gradual, initially relying on word-of-mouth marketing and user feedback to shape product development.  The success of Viaweb suggests that it was a startup with significant potential for further growth and investment.

# %% [markdown]
# # Insert data in batches of 10 in property graph

# %%
index._insert_nodes(nodes_list[1])
# Out:
# Extracting and inferring knowledge graph from text: 100%|██████████| 10/10 [01:29<00:00,  8.95s/it]
# Generating embeddings: 100%|██████████| 1/1 [00:01<00:00,  1.63s/it]
#